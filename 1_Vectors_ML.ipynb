# %%
#distance from origin -> euclidean norm
import numpy as np

#define an n-dimensional vector A
A=np.array([1,2,3,4,5])

# Calculate the Euclidean distance from the origin (L2 norm)
distance =np.linalg.norm(A)

print('Euclidean distance from the origin:', distance)
# Out:
# Euclidean distance from the origin: 7.416198487095663

# %%
# to find euclidean distance in n-D
import numpy as np

# Define two n-dimensional vectors A and B
A = np.array([1, 2, 3, 4, 5])
B = np.array([6, 7, 8, 9, 10])

# Calculate the difference vector
difference = A - B

difference
# Out:
# array([-5, -5, -5, -5, -5])

# %%
# Calculate the Euclidean distance between A and B (L2 norm of the difference)
distance = np.linalg.norm(difference)

print("Euclidean distance between A and B:", distance)
# Out:
# Euclidean distance between A and B: 11.180339887498949

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.distance import euclidean

# 1. Generate 5 random 3D vectors
vectors = np.random.rand(5, 3)

# 2. Assign a random class (0 or 1) to each vector
classes = np.random.randint(0, 2, 5)

# 3. Plot the vectors on a 3D Matplotlib graph
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

for vec, cls in zip(vectors, classes):
    ax.quiver(0, 0, 0, vec[0], vec[1], vec[2], color=("r" if cls == 1 else "b"))


# 4. Get user input for a query point (3D vector)
while True:
    try:
        query_vector = np.array(list(map(float, input("Enter the query point (3D vector) separated by space: ").split())))
        if query_vector.size != 3:
            raise ValueError
        break
    except ValueError:
        print("Invalid input. Please enter three floats separated by space.")

# 5. Calculate the distance from the query vector to the 5 vectors and find the nearest neighbor
distances = [euclidean(query_vector, vec) for vec in vectors]
nearest_neighbor_index = np.argmin(distances)

# 6. Output the class of the nearest neighbor
print("The class of the nearest neighbor is:", classes[nearest_neighbor_index])

# 7. Plot the query vector with a different color
ax.quiver(0, 0, 0, query_vector[0], query_vector[1], query_vector[2], color="g")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")

plt.show()
# Out:
# Enter the query point (3D vector) separated by space: 1 1 1
# The class of the nearest neighbor is: 0

# %%
#generating 100 2D Vectors
import numpy as np
import matplotlib.pyplot as plt

# Generate random 2D data with 100 points
data = np.random.rand(100, 2)


data
# Out:
# array([[9.64105006e-01, 3.85025070e-01],
#        [4.06223096e-02, 4.69747304e-01],
#        [3.21890516e-01, 8.52260621e-01],
#        [8.73287988e-01, 5.58078203e-01],
#        [7.52897503e-01, 2.76907176e-01],
#        [7.95471057e-01, 4.58603716e-01],
#        [3.06619559e-01, 4.11430822e-01],
#        [4.07775370e-02, 2.17874626e-01],
#        [1.91269878e-01, 6.12119266e-01],
#        [6.49332679e-01, 4.85014701e-01],
#        [4.71881026e-01, 5.01031734e-01],
#        [1.87547669e-01, 2.04385406e-01],
#        [7.49178168e-01, 5.51082234e-01],
#        [2.20396411e-01, 2.26234587e-01],
#        [7.57192933e-01, 7.55373668e-02],
#        [4.47430519e-01, 5.40882452e-01],
#        [9.56578830e-01, 2.73603800e-01],
#        [7.38516261e-01, 9.30800291e-01],
#        [7.23415204e-01, 5.24671673e-02],
#        [8.39295943e-01, 7.95238003e-01],
#        [5.89767639e-01, 4.45980816e-01],
#        [3.20038209e-01, 2.87176596e-01],
#        [5.51855915e-02, 4.94243066e-01],
#        [8.37799026e-01, 3.06366777e-01],
#        [4.55092482e-01, 3.02677176e-01],
#        [9.24100692e-01, 9.57153824e-01],
#        [3.70174409e-01, 5.64447809e-01],
#        [8.70412613e-01, 4.46721564e-01],
#        [3.60155802e-01, 3.49264938e-01],
#        [3.09396295e-01, 4.46911094e-01],
#        [7.70534352e-01, 9.92251548e-01],
#        [9.04532509e-01, 6.44009915e-01],
#        [5.61741200e-01, 9.04975092e-01],
#        [5.12280468e-01, 1.51743899e-01],
#        [2.47711019e-01, 9.87560725e-01],
#        [4.39428593e-01, 3.39642815e-01],
#        [2.37170946e-01, 6.50545318e-01],
#        [3.46467700e-01, 7.58050366e-01],
#        [3.94398464e-02, 8.77233497e-01],
#        [3.04092437e-01, 4.65543801e-01],
#        [4.21683845e-02, 4.41627986e-01],
#        [4.95651443e-01, 9.12302327e-01],
#        [8.78868971e-01, 7.43790946e-01],
#        [3.26610876e-01, 8.78587155e-01],
#        [3.97504527e-02, 2.50449081e-01],
#        [2.30774038e-01, 2.44106293e-01],
#        [9.07629972e-01, 4.42656621e-01],
#        [9.76750468e-01, 9.32012330e-01],
#        [5.08480259e-01, 5.23563515e-05],
#        [7.93775612e-01, 1.54303380e-01],
#        [4.29055675e-01, 2.86012393e-01],
#        [2.46471741e-01, 2.86829843e-02],
#        [9.76088740e-01, 1.19844591e-01],
#        [4.73223515e-01, 2.97119185e-01],
#        [8.32266895e-01, 7.47556500e-01],
#        [2.38255757e-01, 4.49709539e-01],
#        [7.26960829e-01, 7.30613669e-02],
#        [8.54993945e-01, 8.11192809e-01],
#        [6.31047929e-01, 4.16866002e-01],
#        [7.58275615e-01, 8.04655219e-01],
#        [5.83915353e-01, 8.60344189e-01],
#        [3.64307877e-01, 1.25688774e-01],
#        [2.42770502e-02, 6.79773741e-01],
#        [7.23870303e-01, 1.65674599e-01],
#        [2.41041544e-01, 5.61163364e-02],
#        [7.80185549e-01, 3.57244268e-01],
#        [3.86786758e-01, 6.05299111e-01],
#        [7.55741899e-01, 7.96587908e-01],
#        [7.48259585e-01, 3.10275456e-01],
#        [2.31356817e-01, 6.60526985e-01],
#        [3.69529307e-01, 3.69918936e-01],
#        [5.70711230e-01, 2.73383340e-01],
#        [4.77082929e-01, 5.94870741e-01],
#        [9.25349347e-01, 7.76520059e-02],
#        [9.78005899e-01, 8.39306459e-01],
#        [3.84369337e-01, 5.93438580e-01],
#        [8.86075301e-01, 7.05752124e-01],
#        [2.96923715e-02, 4.86724944e-01],
#        [4.98809022e-01, 1.35851940e-01],
#        [8.50042233e-01, 5.13938515e-01],
#        [3.79248668e-01, 1.43976814e-01],
#        [2.81221508e-01, 5.11435385e-02],
#        [1.28886211e-01, 3.50562079e-02],
#        [4.75099701e-01, 4.65956455e-01],
#        [6.49636882e-01, 1.92686923e-01],
#        [9.46433481e-02, 1.42639972e-01],
#        [2.95741037e-01, 1.20983206e-01],
#        [2.84205146e-01, 1.94375741e-02],
#        [9.68101140e-02, 7.11714688e-01],
#        [8.05979077e-01, 8.58047251e-01],
#        [8.86424943e-01, 1.07076558e-01],
#        [5.62746553e-01, 8.60806075e-01],
#        [4.16447551e-01, 4.43153181e-01],
#        [6.37747388e-01, 4.43667340e-01],
#        [4.36449812e-01, 7.10325494e-01],
#        [2.00806225e-01, 3.56093159e-01],
#        [4.32038916e-01, 5.67729772e-02],
#        [6.31012638e-01, 4.27997401e-01],
#        [3.06134293e-01, 4.10919556e-01],
#        [8.50168106e-02, 1.95997185e-01]])

# %%
# Plot the original data
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(data[:, 0], data[:, 1], label="Original Data")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Before Mean Centering")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

# %%
# Calculate the mean of the data along each dimension
data_mean = np.mean(data, axis=0)

print(data_mean)
# Perform mean centering
centered_data = data - data_mean
# Out:
# [0.50746036 0.45248235]

# %%
# Plot the mean-centered data
plt.subplot(1, 2, 2)
plt.scatter(centered_data[:, 0], centered_data[:, 1], label="Mean-Centered Data", color="orange")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("After Mean Centering")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate random 2D data with 100 points
data = np.random.rand(100, 2)

# Calculate the mean of the data along each dimension
data_mean = np.mean(data, axis=0)

# Perform mean centering
centered_data = data - data_mean

# Plot the original data
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(data[:, 0], data[:, 1], label="Original Data")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Before Mean Centering")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

# Plot the mean-centered data
plt.subplot(1, 2, 2)
plt.scatter(centered_data[:, 0], centered_data[:, 1], label="Mean-Centered Data", color="orange")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("After Mean Centering")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

plt.show()

# %%
#how to use dot product using numpy
import numpy as np

# Define three vectors
A = np.array([1, 2, 3])
B = np.array([4, 5, 6])

print(np.dot(A, B))
print(A@B)
# Out:
# 32
# 32

# %%
# Check commutative property : A*B
import numpy as np

# Define three vectors
A = np.array([1, 2, 3])
B = np.array([4, 5, 6])
C = np.array([7, 8, 9])

# Calculate dot product using numpy.dot() function
dot_product_AB = np.dot(A, B)
dot_product_BA = np.dot(B, A)

print(dot_product_AB)
print(dot_product_BA)

# Check commutative property: A • B = B • A
if dot_product_AB == dot_product_BA:
    print("The dot product is commutative.")
else:
    print("The dot product is not commutative.")
# Out:
# 32
# 32
# The dot product is commutative.

# %%
# Check distributive property: A • (B + C) = A • B + A • C
dot_product_A_BC = np.dot(A, B + C)
dot_product_AB_plus_AC = np.dot(A, B) + np.dot(A, C)

print(dot_product_A_BC)
print(dot_product_AB_plus_AC)


if dot_product_A_BC == dot_product_AB_plus_AC:
    print("The dot product is distributive.")
else:
    print("The dot product is not distributive.")
# Out:
# 82
# 82
# The dot product is distributive.

# %%
# Define two vectors
A = np.array([1, 2, 3])
B = np.array([-4, -5, -6])
C = np.array([5,5,5])


# Calculate the cosine similarity
cosine_similarity = np.dot(A, B) / (np.linalg.norm(A) * np.linalg.norm(B))

print("Cosine similarity between A and B:", cosine_similarity)

# Calculate the cosine similarity
cosine_similarity = np.dot(A, C) / (np.linalg.norm(A) * np.linalg.norm(C))

print("Cosine similarity between A and C:", cosine_similarity)
# Out:
# Cosine similarity between A and B: -0.9746318461970762
# Cosine similarity between A and C: 0.9258200997725513
